# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.18.2' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'forge'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

elif server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
elif server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

elif server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# /home/codespace/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /workspaces/codespaces-jupyter/Minecraft-server
# Current Time: 21/03/2024 20:52:54
# ^C
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.14":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.14" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2eDKTqjtKY382MWyquaFaIgypUb_2NVBpN7qPX9vkiEhgM168" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      eula.txt	    mods	     server.properties
# banned-players.json  forge.jar	    ops.json	     user_jvm_args.txt
# colabconfig.json     forge.jar.log  run.bat	     usercache.json
# config		     journeymap     run.sh	     usernamecache.json
# crash-reports	     libraries	    scripts	     whitelist.json
# defaultconfigs	     logs	    server-icon.jpg  world
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:13408
# Estas jugando a minecraft: forge en su version: 1.18.2
# La versión de Forge es: 1.18.2-40.2.18
# /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/1.18.2-40.2.18/unix_args.txt
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [06:19:55] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 40.2.18, --fml.mcVersion, 1.18.2, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20220404.173914]
# [06:19:55] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher 9.1.3+9.1.3+main.9b69c82a starting: java version 21.0.2 by Microsoft
# [06:19:55] [main/INFO] [mixin/]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2314!/ Service=ModLauncher Env=SERVER
# [06:19:55] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/fmlcore/1.18.2-40.2.18/fmlcore-1.18.2-40.2.18.jar is missing mods.toml file
# [06:19:55] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/javafmllanguage/1.18.2-40.2.18/javafmllanguage-1.18.2-40.2.18.jar is missing mods.toml file
# [06:19:55] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/lowcodelanguage/1.18.2-40.2.18/lowcodelanguage-1.18.2-40.2.18.jar is missing mods.toml file
# [06:19:56] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/mclanguage/1.18.2-40.2.18/mclanguage-1.18.2-40.2.18.jar is missing mods.toml file
# [06:19:56] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select a dependency jar for JarJar which was passed in as source: flywheel. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/flywheel-forge-1.18.2-0.6.8.a.jar
# [06:19:56] [main/INFO] [ne.mi.fm.lo.mo.JarInJarDependencyLocator/]: Found 1 dependencies adding them to mods collection
# [06:19:59] [main/INFO] [mixin/]: Compatibility level set to JAVA_17
# [06:19:59] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [tictim.paraglider.MixinConnector]
# [06:19:59] [main/INFO] [cp.mo.mo.LaunchServiceHandler/MODLAUNCHER]: Launching target 'forgeserver' with arguments []
# [06:20:00] [main/WARN] [mixin/]: Reference map 'idas.refmap.json' for idas.mixins.json could not be read. If this is a development environment you can ignore this message
# [06:20:00] [main/WARN] [mixin/]: Reference map 'creativecore.mixins.refmap.json' for creativecore.mixins.json could not be read. If this is a development environment you can ignore this message
# [06:20:00] [main/WARN] [mixin/]: Reference map 'smallships-forge-refmap.json' for smallships.mixins.json could not be read. If this is a development environment you can ignore this message
# [06:20:11] [Modding Legacy/blue_skies/Supporters thread/INFO] [ModdingLegacy/blue_skies/Supporter/]: Attempting to load the Modding Legacy supporters list from https://moddinglegacy.com/supporters-changelogs/supporters.txt
# [06:20:12] [modloading-worker-0/INFO] [co.jt.li.LibraryFerret/]: Initialize mod Library Ferret
# [06:20:12] [modloading-worker-0/INFO] [co.jt.li.LibraryFerret/]: Initialized mod Library Ferret
# [06:20:13] [Modding Legacy/blue_skies/Supporters thread/INFO] [ModdingLegacy/blue_skies/Supporter/]: Successfully loaded the Modding Legacy supporters list.
# [06:20:13] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:pufferfish_bucket is now minecraft:bucket.
# [06:20:13] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:salmon_bucket is now minecraft:bucket.
# [06:20:13] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:cod_bucket is now minecraft:bucket.
# [06:20:13] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:tropical_fish_bucket is now minecraft:bucket.
# [06:20:13] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:axolotl_bucket is now minecraft:bucket.
# [06:20:13] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:powder_snow_bucket is now minecraft:bucket.
# [06:20:16] [modloading-worker-0/INFO] [twilightforest/]: Loaded compatibility for mod Tinkers Construct.
# [06:20:16] [modloading-worker-0/INFO] [twilightforest/]: Skipped compatibility for mod undergarden.
# [06:20:16] [modloading-worker-0/INFO] [twilightforest/]: Skipped compatibility for mod immersiveengineering.
# [06:20:16] [modloading-worker-0/INFO] [twilightforest/]: Loaded compatibility for mod Curios.
# [Mouse Tweaks] Disabled because not running on the client.
# [06:20:17] [modloading-worker-0/INFO] [co.tt.re.AbstractRegistrate/]: Detected new forge version, registering events reflectively.
# [06:20:17] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id architectury:sync_ids
# [06:20:17] [modloading-worker-0/INFO] [de.te.va.co.BalanceConfig/]: IceAndFire is loaded -> Adjusting default fire related configuration.
# [06:20:18] [modloading-worker-0/INFO] [ne.mi.co.ForgeMod/FORGEMOD]: Forge mod loading, version 40.2.18, for MC 1.18.2 with MCP 20220404.173914
# [06:20:18] [modloading-worker-0/INFO] [ne.mi.co.MinecraftForge/FORGE]: MinecraftForge v40.2.18 Initialized
# [06:20:18] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.SpiralSpiresModule
# [06:20:18] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.PermafrostModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.NoMoreLavaPocketsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.NewStoneTypesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.NetherObsidianSpikesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.MonsterBoxModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.GlimmeringWealdModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.FairyRingsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.CorundumModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.ChorusVegetationModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.BlossomTreesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.BigStoneClustersModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.BigDungeonModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.world.module.AzaleaWoodModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.VillagersFollowEmeraldsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.VexesDieWithTheirMastersModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.UtilityRecipesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.SnowGolemPlayerHeadsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.SimpleHarvestModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.SignEditingModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.ReplaceScaffoldingModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.ReacharoundPlacingModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.PoisonPotatoUsageModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.PigLittersModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.PatTheDogsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.NoteBlockMobSoundsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.MoreBannerLayersModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.LockRotationModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.HoeHarvestingModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.GrabChickensModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.GlassShardModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.EnhancedLaddersModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.EmotesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.DragonScalesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.DoubleDoorOpeningModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.CompassesWorkEverywhereModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.CampfiresBoostElytraModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.BetterElytraRocketModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.AutomaticRecipeUnlockModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tweaks.module.ArmedArmorStandsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.TrowelModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.SlimeInABucketModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.SkullPikesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.SeedPouchModule
# [06:20:19] [modloading-worker-0/INFO] [be.fl.ex.ExpandAbility/]: ExpandAbility here, who dis?
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.PickarangModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.PathfinderMapsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.ParrotEggsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.EndermoshMusicDiscModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.ColorRunesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.CameraModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.BundleRecipeModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.BottledCloudModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.BeaconRedirectionModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.AncientTomesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.AmbientDiscsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.tools.module.AbacusModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.WraithModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.ToretoiseModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.StonelingsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.ShibaModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.FrogsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.FoxhoundModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.ForgottenModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.mobs.module.CrabsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.QuickArmorSwappingModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.ItemSharingModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.InventorySortingModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.HotbarChangerModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.ExpandedItemInteractionsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.EasyTransferingModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.management.module.ChestsInBoatsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.ZombieVillagersOnNormalModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.SpawnerReplacerModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.OverlayShaderModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.NarratorReadoutModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.GameNerfsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.EnchantmentsBegoneModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.AdjustableChatModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.VariantAnimalTexturesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.UsesForCursesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.UsageTickerModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.SoulCandlesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.MicrocraftingHelperModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.ImprovedTooltipsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.GreenerGrassModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.ChestSearchingModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.BackButtonKeybind
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.client.module.AutoWalkKeybindModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.WoodenPostsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VerticalSlabsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VerticalPlanksModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VariantLaddersModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VariantFurnacesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VariantChestsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VariantBookshelvesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.ThatchModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.SturdyStoneModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.StoolsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.SoulSandstoneModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.ShinglesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.ShearVinesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.RopeModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.OrientalPaletteModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.NetherBrickFenceGateModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.MoreStoneVariantsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.MorePottedPlantsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.MoreBrickTypesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.MidoriModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.LeafCarpetModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.IndustrialPaletteModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.HedgesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.GrateModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.GoldBarsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.GlassItemFrameModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.FramedGlassModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.DuskboundBlocksModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.CompressedBlocksModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.CelebratoryLampsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.RedstoneRandomizerModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.PistonsMoveTileEntitiesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.ObsidianPlateModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.MetalButtonsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.JukeboxAutomationModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.IronRodModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.GravisandModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.FeedingTroughModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.EnderWatcherModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.DispensersPlaceBlocksModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.ChuteModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.automation.module.ChainsConnectBlocksModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.TotemOfHoldingModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.TinyPotatoModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.PipesModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.MatrixEnchantingModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.MagnetsModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.CrateModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.addons.oddities.module.BackpackModule
# [06:20:19] [modloading-worker-0/INFO] [quark/]: Dispatching Module Step CONSTRUCT
# [06:20:36] [main/INFO] [quark/]: Dispatching Module Step REGISTER
# [06:20:37] [main/INFO] [quark/]: Dispatching Module Step POST_REGISTER
# [06:20:37] [main/ERROR] [minecraft/Util]: Adding duplicate key 'ResourceKey[minecraft:worldgen/configured_feature / evilcraft:stone_netherfish]' to registry
# [06:20:37] [main/ERROR] [minecraft/Util]: Adding duplicate key 'ResourceKey[minecraft:worldgen/configured_feature / evilcraft:stone_nether_silverfish_extra]' to registry
# [06:20:37] [main/ERROR] [minecraft/Util]: Adding duplicate key 'ResourceKey[minecraft:worldgen/placed_feature / evilcraft:stone_netherfish]' to registry
# [06:20:37] [main/ERROR] [minecraft/Util]: Adding duplicate key 'ResourceKey[minecraft:worldgen/placed_feature / evilcraft:stone_nether_silverfish_extra]' to registry
# [06:20:37] [main/ERROR] [minecraft/Util]: Adding duplicate key 'ResourceKey[minecraft:worldgen/configured_feature / evilcraft:stone_netherfish]' to registry
# [06:20:37] [main/ERROR] [minecraft/Util]: Adding duplicate key 'ResourceKey[minecraft:worldgen/configured_feature / evilcraft:stone_nether_silverfish_extra]' to registry
# [06:20:37] [main/ERROR] [minecraft/Util]: Adding duplicate key 'ResourceKey[minecraft:worldgen/placed_feature / evilcraft:stone_netherfish]' to registry
# [06:20:37] [main/ERROR] [minecraft/Util]: Adding duplicate key 'ResourceKey[minecraft:worldgen/placed_feature / evilcraft:stone_nether_silverfish_extra]' to registry
# [06:20:39] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `minecraft` for name `shulker_shell`, expected `supplementaries`. This could be a intended override, but in most cases indicates a broken mod.
# [06:20:41] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `evilcraft` for name `blood`, expected `cyclopscore`. This could be a intended override, but in most cases indicates a broken mod.
# [06:20:41] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `evilcraft` for name `blood_flowing`, expected `cyclopscore`. This could be a intended override, but in most cases indicates a broken mod.
# [06:20:41] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `evilcraft` for name `poison`, expected `cyclopscore`. This could be a intended override, but in most cases indicates a broken mod.
# [06:20:41] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `evilcraft` for name `poison_flowing`, expected `cyclopscore`. This could be a intended override, but in most cases indicates a broken mod.
# [06:20:41] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `minecraft` for name `milk`, expected `forge`. This could be a intended override, but in most cases indicates a broken mod.
# [06:20:41] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `minecraft` for name `flowing_milk`, expected `forge`. This could be a intended override, but in most cases indicates a broken mod.
# [06:20:41] [main/WARN] [de.te.va.ef.VampirismNightVisionPotion/]: -------Please ignore the following error!------
# [06:20:41] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `minecraft` for name `night_vision`, expected `vampirism`. This could be a intended override, but in most cases indicates a broken mod.
# [06:20:41] [main/WARN] [de.te.va.ef.VampirismNightVisionPotion/]: -----------------------------------------------
# [06:20:41] [main/INFO] [evilcraft/]: 2205 possible Broom base combinations are ready for flying!
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class com.github.alexthe666.alexsmobs.entity.EntityLeafcutterAnt from class com.github.alexthe666.alexsmobs.entity.EntityDevilsHolePupfish
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class com.github.alexthe666.alexsmobs.entity.EntityMantisShrimp from class com.github.alexthe666.alexsmobs.entity.EntitySkelewag
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class nonamecrackers2.witherstormmod.common.entity.SickenedZombie from class nonamecrackers2.witherstormmod.common.entity.SickenedSkeleton
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class nonamecrackers2.witherstormmod.common.entity.SickenedZombie from class nonamecrackers2.witherstormmod.common.entity.SickenedSpider
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class nonamecrackers2.witherstormmod.common.entity.SickenedZombie from class nonamecrackers2.witherstormmod.common.entity.SickenedCreeper
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CEnumParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.VillagerEntityMCA from class forge.net.mca.util.network.datasync.CDataParameter
# [06:20:43] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class forge.net.mca.entity.GrimReaperEntity from class forge.net.mca.util.network.datasync.CEnumParameter
# [06:20:43] [main/INFO] [ModdingLegacy/blue_skies/]: Loading Config: blue_skies-common.toml
# [06:20:43] [main/INFO] [ModdingLegacy/blue_skies/]: Loading Config: blue_skies-common.toml
# [06:20:43] [Thread-0/INFO] [ModdingLegacy/blue_skies/]: Reloading Config: blue_skies-common.toml
# [06:20:43] [Thread-0/INFO] [ModdingLegacy/blue_skies/]: Reloading Config: blue_skies-common.toml
# [06:20:43] [Thread-0/INFO] [ModdingLegacy/blue_skies/]: Reloading Config: blue_skies-common.toml
# [06:20:43] [Thread-0/INFO] [ModdingLegacy/blue_skies/]: Reloading Config: blue_skies-common.toml
# [06:20:43] [main/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/tinkers_reforged-common.toml is not correct. Correcting
# [06:20:43] [main/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key adaptingModifierCap was corrected from 15.0 to its default, 15.0.
# [06:20:43] [Thread-0/WARN] [ne.mi.fm.co.ConfigFileTypeHandler/CONFIG]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/tinkers_reforged-common.toml is not correct. Correcting
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registering data for structure_gel:biome_dictionary
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registering data for structure_gel:loot_table_alias
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registering data for structure_gel:data_handler_type
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registering data for structure_gel:dynamic_spawner
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Attempting to register unregistered biomes to the biome dictionary. This can be disabled via config
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:temperate_grove to [structure_gel:plains, structure_gel:neutral_temp]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered twilightforest:enchanted_forest to [structure_gel:dry, structure_gel:snowy]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:sierra_badlands to [structure_gel:plains, structure_gel:warm]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:borealis_grove to [structure_gel:wooded, structure_gel:cold]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:cryptic_wastes to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:lush_stacks to [structure_gel:neutral_temp, structure_gel:ocean]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered twilightforest:mushroom_forest to [structure_gel:dry, structure_gel:snowy, structure_gel:mushroom]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:ethereal_islands to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:warped_desert to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:rainbow_beach to [structure_gel:neutral_temp, structure_gel:beach]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:jacaranda_forest to [structure_gel:neutral_temp, structure_gel:jungle]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered twilightforest:highlands to [structure_gel:dry, structure_gel:snowy]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:bulbis_gardens to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:embur_bog to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:dead_sea to [structure_gel:hot, structure_gel:ocean]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:aspen_forest to [structure_gel:wooded, structure_gel:neutral_temp]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:glowstone_gardens to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:viscal_isles to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:windswept_desert to [structure_gel:desert, structure_gel:hot, structure_gel:dry]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:weeping_witch_forest to [structure_gel:wooded, structure_gel:cold]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:nightshade_forest to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:brimstone_caverns to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether, structure_gel:cave]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:twilight_meadow to [structure_gel:wooded, structure_gel:cold]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:atacama_desert to [structure_gel:desert, structure_gel:hot, structure_gel:dry]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:amaranth_fields to [structure_gel:plains, structure_gel:neutral_temp]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:magma_wastes to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:maple_taiga to [structure_gel:spruce_forest, structure_gel:cold]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:araucaria_savanna to [structure_gel:dry, structure_gel:warm, structure_gel:savanna]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered twilightforest:forest to [structure_gel:dry, structure_gel:snowy]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:rose_fields to [structure_gel:plains, structure_gel:neutral_temp]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:bayou to [structure_gel:neutral_temp, structure_gel:swamp]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered twilightforest:thornlands to [structure_gel:dry, structure_gel:snowy]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:shulkren_forest to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered twilightforest:swamp to [structure_gel:dry, structure_gel:snowy]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:arisian_undergrowth to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:temperate_rainforest to [structure_gel:wooded, structure_gel:neutral_temp]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:firecracker_shrubland to [structure_gel:desert, structure_gel:hot]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:red_oak_forest to [structure_gel:wooded, structure_gel:humid, structure_gel:neutral_temp]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:autumnal_taiga to [structure_gel:autumn_forest, structure_gel:spruce_forest, structure_gel:cold]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:white_mangrove_marshes to [structure_gel:neutral_temp, structure_gel:swamp]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:wailing_garth to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:cardinal_tundra to [structure_gel:snowy, structure_gel:cold]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:cika_woods to [structure_gel:wooded, structure_gel:neutral_temp]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:ivis_fields to [structure_gel:neutral_temp, structure_gel:the_end, structure_gel:dry]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered twilightforest:clearing to [structure_gel:dry, structure_gel:snowy]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered quark:glimmering_weald to [structure_gel:neutral_temp]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:weeping_mire to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered twilightforest:dark_forest to [structure_gel:dry, structure_gel:snowy]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered twilightforest:oak_savannah to [structure_gel:dry, structure_gel:snowy]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered terrablender:deferred_placeholder to [structure_gel:neutral_temp, structure_gel:dry]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:frosted_coniferous_forest to [structure_gel:snowy_spruce_forest, structure_gel:snowy, structure_gel:coniferous_forest]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:coconino_meadow to [structure_gel:plains, structure_gel:neutral_temp]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:skyris_vale to [structure_gel:mountain, structure_gel:cold]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:autumnal_forest to [structure_gel:wooded, structure_gel:humid, structure_gel:autumn_forest, structure_gel:cold]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:zelkova_forest to [structure_gel:spruce_forest, structure_gel:cold]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:sythian_torrids to [structure_gel:hot, structure_gel:dry, structure_gel:the_nether]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:dacite_ridges to [structure_gel:mountain, structure_gel:cold]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:black_forest to [structure_gel:spruce_forest, structure_gel:cold]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:allium_fields to [structure_gel:plains, structure_gel:flowery, structure_gel:neutral_temp]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:forgotten_forest to [structure_gel:wooded, structure_gel:neutral_temp]
# [06:20:44] [main/INFO] [ModdingLegacy/structure_gel/]: [Structure Gel] Registered byg:windswept_dunes to [structure_gel:desert, structure_gel:hot, structure_gel:dry]
# [07:34:00] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: entity.evilcraft.broom (vehicle of RealRedHood2000) moved too quickly! 9.282115538559992,1.3011695347156405,-3.7922552089505643
# [07:34:00] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: entity.evilcraft.broom (vehicle of RealRedHood2000) moved too quickly! 10.124292884857823,1.3883784264744037,-4.366898632509901
# [07:34:00] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: entity.evilcraft.broom (vehicle of RealRedHood2000) moved too quickly! 10.922105868175095,1.4706984414379747,-5.006999676467785
# [07:34:00] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: entity.evilcraft.broom (vehicle of RealRedHood2000) moved too quickly! 11.675455758156204,1.546763916324167,-5.703032969412334
# [07:34:00] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: entity.evilcraft.broom (vehicle of RealRedHood2000) moved too quickly! 12.385319196710043,1.6193387187141468,-6.446669131263434
# [07:36:23] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: entity.evilcraft.broom (vehicle of Frosty) moved too quickly! -6.035244005193817,-0.3897416477817046,8.39998475139123
# [07:36:23] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: entity.evilcraft.broom (vehicle of Frosty) moved too quickly! -6.679644064103741,-0.4056092573636221,9.220580436366618
# [07:38:54] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: entity.evilcraft.broom (vehicle of Frosty) moved too quickly! 5.05191380537417,1.318035906315231,8.76212745258772
# [07:38:54] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: entity.evilcraft.broom (vehicle of Frosty) moved too quickly! 5.436632574558644,1.4815069529771137,9.68444371682699
# [07:39:01] [Server thread/INFO] [minecraft/DedicatedServer]: Frosty has made the advancement [The Lighthouse]
# [07:39:22] [Server thread/INFO] [minecraft/DedicatedServer]: RealRedHood2000 has made the advancement [Ice Bucket Challenge]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [07:39:59] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2025ms or 40 ticks behind
# [07:40:55] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: entity.evilcraft.broom (vehicle of Frosty) moved wrongly! 0.3466741016547985
# [07:40:55] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: entity.evilcraft.broom (vehicle of TheReadyh) moved wrongly! 0.3630482855127184
# >
